# %% [markdown]
# TASK #1

# %%
import pandas as pd

# Create the dataset
data = {
    "Order_ID": [1001,1002,1003,1004,1005,1006,1007,1008,1009,1010],
    "Customer_Name": ["  Ali Khan  ", "Amna Raza", " John  Doe ", "Sara Ali", "Ali Khan", "", "Hadi ", "Mehak   Noor", "Sameer Khan", "Ahsan Ali"],
    "Email": ["ali.khan@example.com", "amna.raza@example", "john.doe@example.com", "sara.ali@example.com", "ali.khan@example.com", "missing@example.com", "hadi123@example.com", "mehak.noor@example.com", "sameer.khan@gmail.com", "ahsan.example.com"],
    "City": ["lahore", "Karachi", "LAHORE", "Islamabad", "lahore", "karachi", "Quetta", "ISLAMABAD", "Peshawar", "Lahore"],
    "Product_Name": [" Laptop@@", "Mobile##", " Headphones**", " Charger**", "Laptop@@", "Mobile##", " USB Cable!!", "Mouse$$", "Keyboard%%", "Laptop@@"],
    "Sales": [55000, 45000, 8000, 1500, 55000, None, 900, 1200, 2000, 60000],
    "Region": ["South","South","South","North","South","South","West","North","North","South"]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("sales_data.csv", index=False)

print("sales_data.csv has been created successfully!")
# Out:
# sales_data.csv has been created successfully!

# %%
import pandas as pd
df = pd.read_csv('sales_data.csv')
print(df.isnull().sum())
# Out:
# Order_ID         0
# Customer_Name    1
# Email            0
# City             0
# Product_Name     0
# Sales            1
# Region           0
# dtype: int64

# %% [markdown]
# TASK #2

# %%
clean_df = df.dropna()
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City   Product_Name  \
# 0      1001    Ali Khan      ali.khan@example.com     lahore       Laptop@@
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile##
# 2      1003    John  Doe     john.doe@example.com     LAHORE   Headphones**
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger**
# 4      1005      Ali Khan    ali.khan@example.com     lahore       Laptop@@
# 5      1006           NaN     missing@example.com    karachi       Mobile##
# 6      1007         Hadi      hadi123@example.com     Quetta    USB Cable!!
# 7      1008  Mehak   Noor  mehak.noor@example.com  ISLAMABAD        Mouse$$
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard%%
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop@@
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# ...

# %% [markdown]
# TASK #3

# %%
df['Sales'].fillna(df['Sales'].mean(), inplace=True)
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City   Product_Name  \
# 0      1001    Ali Khan      ali.khan@example.com     lahore       Laptop@@
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile##
# 2      1003    John  Doe     john.doe@example.com     LAHORE   Headphones**
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger**
# 4      1005      Ali Khan    ali.khan@example.com     lahore       Laptop@@
# 5      1006           NaN     missing@example.com    karachi       Mobile##
# 6      1007         Hadi      hadi123@example.com     Quetta    USB Cable!!
# 7      1008  Mehak   Noor  mehak.noor@example.com  ISLAMABAD        Mouse$$
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard%%
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop@@
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# ...

# %% [markdown]
# TASK#4

# %%
duplicates = df.duplicated().sum()
df.drop_duplicates(inplace=True)
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City   Product_Name  \
# 0      1001    Ali Khan      ali.khan@example.com     lahore       Laptop@@
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile##
# 2      1003    John  Doe     john.doe@example.com     LAHORE   Headphones**
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger**
# 4      1005      Ali Khan    ali.khan@example.com     lahore       Laptop@@
# 5      1006           NaN     missing@example.com    karachi       Mobile##
# 6      1007         Hadi      hadi123@example.com     Quetta    USB Cable!!
# 7      1008  Mehak   Noor  mehak.noor@example.com  ISLAMABAD        Mouse$$
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard%%
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop@@
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# ...

# %% [markdown]
# TASK #5

# %%
df['Customer_Name'] = df['Customer_Name'].str.strip()
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City   Product_Name  \
# 0      1001      Ali Khan    ali.khan@example.com     lahore       Laptop@@
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile##
# 2      1003     John  Doe    john.doe@example.com     LAHORE   Headphones**
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger**
# 4      1005      Ali Khan    ali.khan@example.com     lahore       Laptop@@
# 5      1006           NaN     missing@example.com    karachi       Mobile##
# 6      1007          Hadi     hadi123@example.com     Quetta    USB Cable!!
# 7      1008  Mehak   Noor  mehak.noor@example.com  ISLAMABAD        Mouse$$
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard%%
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop@@
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# ...

# %% [markdown]
# TASK#6

# %%
df['City'] = df['City'].str.title()
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City   Product_Name  \
# 0      1001      Ali Khan    ali.khan@example.com     Lahore       Laptop@@
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile##
# 2      1003     John  Doe    john.doe@example.com     Lahore   Headphones**
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger**
# 4      1005      Ali Khan    ali.khan@example.com     Lahore       Laptop@@
# 5      1006           NaN     missing@example.com    Karachi       Mobile##
# 6      1007          Hadi     hadi123@example.com     Quetta    USB Cable!!
# 7      1008  Mehak   Noor  mehak.noor@example.com  Islamabad        Mouse$$
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard%%
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop@@
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# ...

# %%
df['City'] = df['City'].str.title()
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City   Product_Name  \
# 0      1001      Ali Khan    ali.khan@example.com     Lahore       Laptop@@
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile##
# 2      1003     John  Doe    john.doe@example.com     Lahore   Headphones**
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger**
# 4      1005      Ali Khan    ali.khan@example.com     Lahore       Laptop@@
# 5      1006           NaN     missing@example.com    Karachi       Mobile##
# 6      1007          Hadi     hadi123@example.com     Quetta    USB Cable!!
# 7      1008  Mehak   Noor  mehak.noor@example.com  Islamabad        Mouse$$
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard%%
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop@@
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# ...

# %% [markdown]
# Task #7

# %%
df['Product_Name'] = df['Product_Name'].str.replace('[^A-Za-z0-9 ]+', '', regex=True)
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City Product_Name  \
# 0      1001      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile
# 2      1003     John  Doe    john.doe@example.com     Lahore   Headphones
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger
# 4      1005      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 5      1006           NaN     missing@example.com    Karachi       Mobile
# 6      1007          Hadi     hadi123@example.com     Quetta    USB Cable
# 7      1008  Mehak   Noor  mehak.noor@example.com  Islamabad        Mouse
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# 5  25400.0  South
# ...

# %% [markdown]
# TASK#8

# %%
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City Product_Name  \
# 0      1001      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile
# 2      1003     John  Doe    john.doe@example.com     Lahore   Headphones
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger
# 4      1005      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 5      1006           NaN     missing@example.com    Karachi       Mobile
# 6      1007          Hadi     hadi123@example.com     Quetta    USB Cable
# 7      1008  Mehak   Noor  mehak.noor@example.com  Islamabad        Mouse
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# 5  25400.0  South
# ...

# %% [markdown]
# TASK#9

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1
df.loc[(df['Sales'] < Q1 - 1.5*IQR) | (df['Sales'] > Q3 + 1.5*IQR), 'Sales'] = df['Sales'].median()
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City Product_Name  \
# 0      1001      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 1      1002     Amna Raza       amna.raza@example    Karachi       Mobile
# 2      1003     John  Doe    john.doe@example.com     Lahore   Headphones
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger
# 4      1005      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 5      1006           NaN     missing@example.com    Karachi       Mobile
# 6      1007          Hadi     hadi123@example.com     Quetta    USB Cable
# 7      1008  Mehak   Noor  mehak.noor@example.com  Islamabad        Mouse
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard
# 9      1010     Ahsan Ali       ahsan.example.com     Lahore       Laptop
#
#      Sales Region
# 0  55000.0  South
# 1  45000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# 5  25400.0  South
# ...

# %% [markdown]
# TASK#11

# %%
import re
df = df[df['Email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$', na=False)]
print(df)
# Out:
#    Order_ID Customer_Name                   Email       City Product_Name  \
# 0      1001      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 2      1003     John  Doe    john.doe@example.com     Lahore   Headphones
# 3      1004      Sara Ali    sara.ali@example.com  Islamabad      Charger
# 4      1005      Ali Khan    ali.khan@example.com     Lahore       Laptop
# 5      1006           NaN     missing@example.com    Karachi       Mobile
# 6      1007          Hadi     hadi123@example.com     Quetta    USB Cable
# 7      1008  Mehak   Noor  mehak.noor@example.com  Islamabad        Mouse
# 8      1009   Sameer Khan   sameer.khan@gmail.com   Peshawar     Keyboard
#
#      Sales Region
# 0  55000.0  South
# 2   8000.0  South
# 3   1500.0  North
# 4  55000.0  South
# 5  25400.0  South
# 6    900.0   West
# 7   1200.0  North
# 8   2000.0  North

# %% [markdown]
# task#10

# %%
import pandas as pd

# Create the dataset
data = {
    "Order_ID": [1001,1002,1003,1004,1005,1006,1007,1008,1009,1010],
    "Customer_Name": ["  Ali Khan  ", "Amna Raza", " John  Doe ", "Sara Ali", "Ali Khan", "", "Hadi ", "Mehak   Noor", "Sameer Khan", "Ahsan Ali"],
    "Email": ["ali.khan@example.com", "amna.raza@example", "john.doe@example.com", "sara.ali@example.com", "ali.khan@example.com", "missing@example.com", "hadi123@example.com", "mehak.noor@example.com", "sameer.khan@gmail.com", "ahsan.example.com"],
    "City": ["lahore", "Karachi", "LAHORE", "Islamabad", "lahore", "karachi", "Quetta", "ISLAMABAD", "Peshawar", "Lahore"],
    "Product_Name": [" Laptop@@", "Mobile##", " Headphones**", " Charger**", "Laptop@@", "Mobile##", " USB Cable!!", "Mouse$$", "Keyboard%%", "Laptop@@"],
    "Sales": [55000, 45000, 8000, 1500, 55000, None, 900, 1200, 2000, 60000],
    "Region": ["South","South","South","North","South","South","West","North","North","South"]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("sales_data2.csv", index=False)

print("sales_data.csv has been created successfully!")
# Out:
# sales_data.csv has been created successfully!
